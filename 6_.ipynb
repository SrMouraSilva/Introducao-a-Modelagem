# %% [markdown]
# <a href="https://colab.research.google.com/github/SrMouraSilva/Modelagem-matematica-trabalho-final/blob/main/6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Simulação de modelos dinâmicos
#
# Venho aqui informar os exercícios que devem ser feitos e entregues até às 23h59 do dia 27/9, domingo, referente à Atividade desse módulo de método computacionais para problemas de otimização. A seleção de 10 exercícios do capítulo 6 são: 6.7, 6.11, 6.12, 6.13, 6.14, 6.19, 6.21, 6.22, 6.26 e 6.27.
#
# Nessa atividade, cada grupo deve entregar:
# (i) Relatório de experimentos com a solução obtida para cada um dos problemas;
# (ii) Listagem do código fonte usado para resolver os problemas. Vale ressaltar que a  linguagem de programação é escolhida pelo grupo. O importante que me enviem o código fonte e informem qual linguagem escolhida;
# (iii) Manual de uso do programa computacional implementado. Esse manual deve informar principalmente como entrar com os dados no programa, quais os pré-requisitos para a execução e como ler os dados de saída;
# (iv) Produzir um vídeo, de no máximo 30min, por um ou todos os membros do grupo apresentando as suposições das variáveis e parâmetros, a modelagem matemática escolhida e os resultados obtidos.
#
# Obs.: Caso o tamanho do vídeo inviabilize a submissão dessa atividade na plataforma do Classroom, vocês podem disponibilizar o link de onde eu possa assistir ao vídeo.

# %% [markdown]
# ### Manual
#
# Os exercícios foram desenvolvidos utilizando a linguagem de programação Python 3. Eles foram desenvolvidos utilizando a ferramenta Google Colaboratory, também conhecida como Google Collab. O Google Collab é uma versão do Jupyter Notebook disponibilizada online e gratuitamente pela Google. Este formato foi escolhido para facilitar a relação entre o desenvolvimento matemático e sua respectiva implementação para cada questão.
#
# Um notebook corresponde a um arquivo composto de uma lista de células. Uma célula pode ser de texto e de código. Em um notebook, o desenvolvedor vai construindo o raciocínio lógico em blocos e comentando o andamento em texto no formato markdown. Nos blocos de texto também é aceito expressões matemáticas em formato latex.
#
# **Uma rápida introdução de uso**
#
# Você pode visualizar o índice da questão clicando no botão índice (![image.png](data:image/png;base64,...)), localizado no menu a esquerda. Ao clicar, o índice será exibido:
#
# ![image.png](data:image/png;base64,...)
#
# Ao abrir o arquivo no navegador, você não poderá executá-lo.
#
# ![image.png](data:image/png;base64,...)
#
# Para fazer alguma alteração, você deverá copiá-lo para seu Google Drive:![image.png](data:image/png;base64,...)
#
# Uma célula de código pode ser executada pressionando o botão ilustrado na figura abaixo:
# ![image.png](data:image/png;base64,...)
#
#
# Dado que o conteúdo das células ficam carregados em memória pela ordem de execução destas, o desenvolvedor deve ter cuidado ao executar as células de forma aleatória. Recomenda-se que, caso seja mudado uma célula, que ele mande executar todas as células anteriores a célula alterada, partindo da primeira até a célula alterada. Uma dica para facilitar é acessar a opção **(menu) Ambiente de execução > (opção) Reiniciar e Executar Tudo**, para executar todas as células em ordem.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Vídeo

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('n8cKGRikdgk')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/n8cKGRikdgk"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Exercícios
#
# Cada questão pode ser acessada pelos seus respectivos links. Foi adicionado um texto resumo das questões e dos itens para facilitar uma ambientação da questão.
#
# * [**Questão 6.7**](https://colab.research.google.com/drive/1Rr3wk2I4r_s_v9wjceYdgSFe5R7AV4bt): Variação do problema da população de baleias e de fins (Exercício 4.5).
#     * [x] a) Simulação do comportamento usando a técnica da Seção 6.2
#     * [x] b) Sensibilidade do modelo (a)
#     * [x] c) Sensibilidade do modelo (a) para taxa de crescimento intrísseca
#     * [x] d) Sensibilidade do modelo (a) para o coeficiente de competição
# * [**Questão 6.11**](https://colab.research.google.com/drive/1iQHNc2KDBfgVmVKPRJmD8hOX-Iq7611I): Variação do exercício de baleias e krills (Exercício 4.7)
#   * [x] a) Determinar os pontos de equilíbrio por simulação usando a técnica da Seção 6.2
#   * [x] b) Descrição de comportamento após um desastre natural
#   * [x] c) Descrição de comportamento caça de baleias
#   * [x] d) Sensibilidade do modelo
# * [**Questão 6.12**](https://colab.research.google.com/drive/1uLSzFsLnc2KPcWgsrz3kiY4Snp5BrdVf): Variação do problema das árvores (Exemplo 5.1)
#   * [x] a) Simular e definir quando a população atinge 90%
#   * [x] b) Determinar o ponto de maior crescimento da biomassa de árvores de  madeira dura
#   * [x] c) Determinar o ponto em que o valor da floresta cresce com a taxa mais alta
#
# * [**Questão 6.13**](https://colab.research.google.com/drive/1lWeZBanNFY87sPmbz9ZbC2nDoVfcxFQ3): Continuação do problema 6.12. Aplicação de _clear-cutting_ (corte raso) para extrair árvores (e planta-las novamente)
#   * [x] a) Melhor política de colheita de "madeira", onde o replantio é de 100 tons/acre de maderia macia e de madeira dura
#   * [x] b) Melhor política de colheita de "madeira", onde o replantio é de somente 200 tons/acre de madeira dura
#   * [x] c) Melhor política de colheita de "madeira", onde o replantio é de somente 200 tons/acre de madeira macia
#   * [x] d) Política de _clear-cutting_ ideal. Quando consideraria em vender a terra?
# * [**Questão 6.14**](https://colab.research.google.com/drive/1v_1DHAt2obwSvzNX3JqEi7qk8kukrkpX): Variação do problema do Exercício 4.5 (competição de baleias)
#   * [x] a) Simulação com o Método de Euler e análise de sensibilidade
#   * [x] b) Repetir a), mas variando
#   * [x] c) Desenhar _complete phase portrait_
#   * [x] d) Indicar a região no _phase portrait_ onde há a extinção de ao menos uma espécie
# * [**Questão 6.19**](https://colab.research.google.com/drive/1C38KlOiXqbR0yTEC_1K6kw5anSp9oT7r): Problema do pêndulo
#   * [x] a) Simular usando o método de Euler o comportamento do pêndulo. Fazer os cinco passos (_five-steps_)
#   * [x] b) Análise de sensibilidade da elasticidade do preço para televisões de 19 polegadas
#   * [x] c) Análise de sensibilidade da elasticidade do preço para televisões de 21 polegadas
#   * [ ] d) TODO Comparação de resultados
# * [**Questão 6.21**](https://colab.research.google.com/drive/12kF8SsiUCihOzOWziDyNyNn_qqn2jzo0): Implementação do método Runge–Kutta
#   * [x] a) Implementar método Runge-Kutta
#   * [x] b) Verificar implementação com a equação 5.18 do Capítulo 5
#   * [x] c) Verificar resultados nas figuras 6.20 e 6.21 do problema do circuito RCL do exemplo 6.3
# * [**Questão 6.22**](https://colab.research.google.com/drive/1XJLJQbB4bMT0lQp3tJMHzFtCcqGTt6L2): Variação do Exemplo 6.4
#   * [x] a) Simular usando algoritmo de Euler
#   * [x] b) Variar $h$ e analisar sensibilidade
#   * [x] c) Variar $h$ e $\alpha$ e analisar sensibilidade
#   * [x] d) Variar $h$ com uma população inicial diferente de $a)$ e analisar sensibilidade
# * [**Questão 6.26**](https://colab.research.google.com/drive/1pQJRZ_6GaucDEf_7VcRJI2XxBlltctrY): Variação do problema do clima (Exemplo 6.6)
#   * [x] a) Reproduzir Figura 6.33 ($x_1$ vs $x_2$)
#   * [x] b) Plotar $x_1$ vs $x_3$ com análise de sensibilidade
#   * [x] c) Plotar $x_1$ vs $x_3$ com análise de sensibilidade com outros valores iniciais
#   * [x] d) Fazer item $b)$, mas variando $r$
# * [**Questão 6.27**](https://colab.research.google.com/drive/14cpho2fqfwngmOC-suVQu6UYt6c0PEaq): Variação do problema do Exemplo 3.3
#   * [x] a) Reproduzir Figura 6.35 ($x_1$ vs $x_2$)
#   * [x] b) Repetir $a)$, mas variando o tamanho do passo $h$
#   * [x] c) Definir $E^+$ e simular para verificar se a solução continua neste ponto
#   * [x] d) Veificar se $E^+$ encontrado em $c)$ é estável e quando ele é estável.
